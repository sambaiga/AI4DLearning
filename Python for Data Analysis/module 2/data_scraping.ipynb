# %% [markdown]
# # <img style="float: left; padding-right: 100px; width: 300px" src="images/logo.png">AI4SG Bootcamp:
#
#
#
# ## Module 2D: Data Scraping
#
#
# **Authors:** Martha Shaka
#
# ---
#
# ### What is Data scraping
# It is commonly defined as a system where a technology extracts data from a particular codebase or program. Data scraping provides results for a variety of uses and automates aspects of data aggregation.
# Most common data scraping is *web scraping*, is the process of importing information from a website into a spreadsheet or
# local file saved on your computer. It’s one of the most efficient ways to get data from the web, and in some cases to channel
# that data to another website.
# Data scraping has a vast number of applications – it’s useful in just about any case where data needs to be moved from one place to another

# %% [markdown]
# #### Uses of data scraping include:
# <ol start="1">
# <li>Research for web content/business intelligence </li>
# <li>Pricing for travel booker sites/price comparison sites </li>
# <li>Finding sales leads/conducting market research by crawling public data sources (e.g. Yell and Twitter) </li>
# <li>Sending product data from an e-commerce site to another online vendor (e.g. Google Shopping)</li>
# </ol>

# %% [markdown]
# In this lab, we'll scrape 2019 A level Results:
#
# https://onlinesys.necta.go.tz/results/2019/acsee/acsee.htm .
#
# We'll walk through scraping the list pages for the school names/urls

# %% [markdown]
# Although many programming languages offer libraries for web information retrieval and analysis,
# we will be focusing on the Python data analysis ecosystem given its popularity and capabilities.

# %% [markdown]
# # Table of Contents
# <ol start="0">
# <li> Learning Goals </li>
# <li> Exploring the Web pages and downloading them</li>
# <li> Parse the page, extract school urls </li>
# <li> Parse a school page, extract student list with results </li>
# <li> Set up a pipeline for fetching and parsing</li>
# </ol>

# %% [markdown]
# ## Learning Goals
#
# Understand the structure of a web page. Use Beautiful soup to scrape content from these web pages.
#
# *This lab corresponds to lectures 2, 3 and 4 and maps on to homework 1 and further.*

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)

# %%
import time, requests

# %% [markdown]
# ## 1. Exploring the web pages and downloading them
#
# We're going to capture infromation on the from six NECTA results list for school.

# %% [markdown]
# To getch this page we use the `requests` module. But are we allowed to do this? Lets check:
#
# https://onlinesys.necta.go.tz/results/2019/acsee/acsee.htm
#
# Yes we are.

# %%
URLSTART="https://onlinesys.necta.go.tz/results/2019/acsee/acsee.htm"
url = URLSTART
print(url)
page = requests.get(url)
# Out:
# https://onlinesys.necta.go.tz/results/2019/acsee/acsee.htm

# %% [markdown]
# We can see properties of the page. Most relevant are `status_code` and `text`. The former tells us  if the web-page was found, and if found , ok. (See lecture notes.)

# %%
page.status_code # 200 is good
# Out:
# 200

# %%
page.text[:1000]
# Out:
# '\ufeff<HTML>\r\n<HEAD>\r\n<META HTTP-EQUIV="Content-Type" CONTENT="text/html; charset=windows-1252">\r\n<HEAD>\r\n<BODY TEXT="#000080" LINK="#0000ff" VLINK="#800080" BGCOLOR="LIGHTYELLOW">\r\n<FONT COLOR="#800080"><H2>NATIONAL EXAMINATIONS COUNCIL OF TANZANIA</H2>\r\n<H3><U> ACSEE 2019 EXAMINATION RESULTS ENQUIRIES </U></H3></FONT>\r\n<BR>\r\n<TABLE BORDER=0 CELLSPACING=0 WIDTH="75%" ALIGN="CENTER" >\r\n<TR ><TD WIDTH="100%" VALIGN="MIDDLE"><B><FONT FACE="Arial" SIZE=2><P ALIGN="CENTER">CLICK ANY LETTER BELOW TO FILTER CENTRES BY ALPHABET</B></FONT></TD></TR>\r\n</TABLE>\r\n<TABLE BORDER CELLSPACING=1 WIDTH="75%" ALIGN="CENTER" >\r\n<TR> <TD WIDTH="10%" VALIGN="MIDDLE" BGCOLOR="LIGHTGREEN">\r\n<B><FONT FACE="Arial" SIZE=3><P ALIGN="CENTER" ><A HREF="index.htm">ALL CENTRES\r\n <TD WIDTH="2.5%" VALIGN="MIDDLE" BGCOLOR="LIGHTBLUE">\r\n<B><FONT FACE="Arial" SIZE=3><P ALIGN="CENTER"><A HREF="indexfiles/index_a.htm">A\r\n</A></B></FONT></TD>\r\n <TD WIDTH="2.5%" VALIGN="MIDDLE" BGCOLOR="LIGHTBLUE">\r\n<B><FONT FACE="Arial" SIZE=3><'

# %% [markdown]
# Let us write a loop to fetch students results for 2 schools with code p0104 and p0110 from goodreads. Notice the use of a format string. This is an example of old-style python format strings

# %%
URLSTART="https://onlinesys.necta.go.tz/results/2019/acsee/results/"
SCHOOL=["p0104","p0110"]
for i in range(0,2):
    bookpage=str(i)
    stuff=requests.get(URLSTART+SCHOOL[i]+".htm")
    filetowrite="files/school"+ '%02d' % i + ".html"
    print("FTW", filetowrite)
    fd=open(filetowrite,"w",encoding="utf-8")
    fd.write(stuff.text)
    fd.close()
    time.sleep(2)
# Out:
# FTW files/school00.html
# FTW files/school01.html

# %% [markdown]
# ## 2. Parse the page, extract school urls
#
# Notice how we do file input-output, and use beautiful soup in the code below. The `with` construct ensures that the file being read is closed, something we do explicitly for the file being written.

# %%
from bs4 import BeautifulSoup

# %% [markdown]
# Getting the html of the page is just the first step. Next step is to create a Beautiful Soup object from the html.
# This is done by passing the html to the BeautifulSoup() function.
# The Beautiful Soup package is used to parse the html, that is, take the raw html text and break it into Python objects. The second argument 'lxml' is the html parser whose details you do not need to worry about at this point.

# %%
filetoread="files/school00.html"
print("FTW", filetoread)
with open(filetoread) as fdr:
    data = fdr.read()
    soup = BeautifulSoup(data, 'html.parser')
print(soup)
# Out:
# FTW files/school00.html
# ï»¿<html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <head>
# <body bgcolor="LIGHTBLUE" link="#0000ff" text="#000080" vlink="#800080">
# <font color="#800080"><h2>NATIONAL EXAMINATIONS COUNCIL OF TANZANIA</h2>
# <h1><p align="LEFT"> ACSEE 2019 EXAMINATION RESULTS</p></h1>
# <h3><p align="LEFT">P0104 BWIRU BOYS' SECONDARY SCHOOL CENTRE
#
# <h3>DIV-I = 1;  DIV-II = 13;  DIV-III = 41;  DIV-IV = 15;  DIV-0 = 14  </h3></p></h3></font>
# </body></head></head></html>
# <table bgcolor="LIGHTYELLOW" border="" cellspacing="2" width="70%">
# <tr><td valign="MIDDLE" width="6%">
# <p align="CENTER"><b><font face="Courier" size="2">CNO</font></b></p></td></tr></table>
# <td valign="MIDDLE" width="4%">
# <b><font face="Courier" size="2"><p align="CENTER">SEX</p></font></b></td>
# <td valign="MIDDLE" width="6%">
# <b><font face="Courier" size="2"><p align="CENTER">AGGT</p></font></b></td>
# <td valign="MIDDLE" width="4%">
# <b><font face="Courier" size="2"><p align="CENTER">DIV</p></font></b></td>
# <td valign="MIDDLE" width="58%">
# <b><font face="Courier" size="2"><p align="LEFT">DETAILED SUBJECTS
#
# </p></font></b></td>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0501</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 18</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   GEOGR - 'E'   CHEMISTRY - 'F'   BIOLOGY - 'S'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0502</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 16</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'F'   KISWAHILI - 'C'   ENGLISH - 'S'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0503</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 9</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">I</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'D'   KISWAHILI - 'B'   ENGLISH - 'C'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0504</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 18</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   HISTORY - 'F'   GEOGR - 'S'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0505</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 16</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'E'   GEOGR - 'D'   BAM - 'F'   ECONOMICS - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0506</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 14</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'E'   GEOGR - 'D'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0507</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 14</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   HISTORY - 'E'   KISWAHILI - 'C'   ENGLISH - 'S'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0508</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 18</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'F'   KISWAHILI - 'D'   ENGLISH - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0509</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 11</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">II</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'D'   KISWAHILI - 'B'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0510</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 12</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">II</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   HISTORY - 'E'   KISWAHILI - 'C'   ENGLISH - 'D'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0511</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 13</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   HISTORY - 'D'   GEOGR - 'E'   ENGLISH - 'D'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0512</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 13</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'F'   KISWAHILI - 'B'   ENGLISH - 'D'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0513</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 16</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'S'   KISWAHILI - 'E'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0514</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 14</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'F'   KISWAHILI - 'C'   ENGLISH - 'D'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0515</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 12</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">II</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   HISTORY - 'S'   KISWAHILI - 'B'   ENGLISH - 'D'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0516</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 15</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'F'   KISWAHILI - 'C'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0517</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 14</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - 'C'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0518</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 12</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">II</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'E'   GEOGR - 'D'   ENGLISH - 'C'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0519</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 14</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'D'   GEOGR - 'E'   BAM - 'F'   ECONOMICS - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0520</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 16</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'F'   KISWAHILI - 'C'   ENGLISH - 'S'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0521</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">ABS</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'X'   HISTORY - 'X'   KISWAHILI - 'X'   ENGLISH - 'X'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0522</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 13</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'S'   KISWAHILI - 'B'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0523</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 17</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   HISTORY - 'F'   KISWAHILI - 'D'   ENGLISH - 'S'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0524</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 11</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">II</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'E'   KISWAHILI - 'C'   ENGLISH - 'C'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0525</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 13</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'E'   KISWAHILI - 'C'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0526</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 13</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'E'   KISWAHILI - 'D'   ENGLISH - 'D'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0527</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 13</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'E'   GEOGR - 'E'   KISWAHILI - 'C'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0528</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">BAM - 'F'   ECONOMICS - 'D'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0529</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">ABS</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'X'   HISTORY - 'X'   KISWAHILI - 'X'   ENGLISH - 'X'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0530</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 11</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">II</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'E'   KISWAHILI - 'B'   ENGLISH - 'D'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0531</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 19</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   PHYSICS - 'F'   CHEMISTRY - 'F'   BIOLOGY - 'E'   BAM - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0532</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 18</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'S'   GEOGR - 'E'   ENGLISH - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0533</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">ABS</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'X'   PHYSICS - 'X'   CHEMISTRY - 'X'   BIOLOGY - 'X'   BAM - 'X'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0534</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 16</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'S'   KISWAHILI - 'D'   ENGLISH - 'S'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0535</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 16</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'F'   KISWAHILI - 'C'   ENGLISH - 'S'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0536</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 16</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   GEOGR - 'D'   CHEMISTRY - 'F'   BIOLOGY - 'E'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0537</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 15</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'E'   GEOGR - 'E'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0538</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 12</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">II</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   HISTORY - 'E'   KISWAHILI - 'B'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0539</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 21</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">0</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   PHYSICS - 'F'   CHEMISTRY - 'F'   BIOLOGY - 'F'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0540</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 16</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   GEOGR - 'D'   PHYSICS - 'E'   ADV/MATHS - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0541</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">ABS</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'X'   PHYSICS - 'X'   CHEMISTRY - 'X'   BIOLOGY - 'X'   BAM - 'X'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0542</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">ABS</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">PHYSICS - 'X'   CHEMISTRY - 'X'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0543</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 12</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">II</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'E'   GEOGR - 'D'   KISWAHILI - 'C'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0544</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 21</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">0</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   PHYSICS - 'F'   CHEMISTRY - 'F'   ADV/MATHS - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0545</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 17</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'F'   KISWAHILI - 'D'   ENGLISH - 'S'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0546</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 18</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">PHYSICS - 'S'   CHEMISTRY - 'F'   BIOLOGY - 'E'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0547</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 14</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'D'   GEOGR - 'E'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0548</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 10</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">II</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'D'   KISWAHILI - 'B'   ENGLISH - 'D'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0549</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 21</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">0</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   GEOGR - 'F'   CHEMISTRY - 'F'   BIOLOGY - 'F'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0550</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 20</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">0</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">PHYSICS - 'F'   CHEMISTRY - 'F'   BIOLOGY - 'S'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0551</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 15</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'E'   GEOGR - 'E'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0552</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">BIOLOGY - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0553</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 15</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'E'   KISWAHILI - 'D'   ENGLISH - 'S'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0554</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">ABS</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">CHEMISTRY - 'X'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0555</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 21</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">0</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   PHYSICS - 'F'   CHEMISTRY - 'F'   ADV/MATHS - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0556</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">ABS</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'X'   PHYSICS - 'X'   CHEMISTRY - 'X'   ADV/MATHS - 'X'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0557</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 19</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   GEOGR - 'E'   CHEMISTRY - 'F'   BIOLOGY - 'F'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0558</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   GEOGR - 'E'   CHEMISTRY - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0559</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">ABS</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">PHYSICS - 'X'   CHEMISTRY - 'X'   ADV/MATHS - 'X'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0560</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 12</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">II</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'D'   GEOGR - 'E'   KISWAHILI - 'C'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0561</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 14</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'D'   GEOGR - 'S'   ENGLISH - 'D'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0562</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 18</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'S'   GEOGR - 'E'   ENGLISH - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0563</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 13</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'E'   KISWAHILI - 'C'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0564</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 15</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   GEOGR - 'E'   CHEMISTRY - 'E'   BIOLOGY - 'E'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0565</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">ABS</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">PHYSICS - 'X'   CHEMISTRY - 'X'   BIOLOGY - 'X'   BAM - 'X'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0566</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 21</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">0</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   PHYSICS - 'F'   CHEMISTRY - 'F'   BIOLOGY - 'F'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0567</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 14</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'E'   GEOGR - 'D'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0568</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 21</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">0</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   PHYSICS - 'F'   CHEMISTRY - 'F'   ADV/MATHS - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0569</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 20</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">0</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   PHYSICS - 'F'   CHEMISTRY - 'F'   BIOLOGY - 'S'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0570</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 15</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'F'   KISWAHILI - 'C'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0571</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">HISTORY - 'E'   GEOGR - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0572</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 21</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">0</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   GEOGR - 'F'   CHEMISTRY - 'F'   BIOLOGY - 'F'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0573</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">ABS</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'X'   HISTORY - 'X'   KISWAHILI - 'X'   ENGLISH - 'X'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0574</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 19</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   PHYSICS - 'F'   CHEMISTRY - 'F'   BIOLOGY - 'E'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0575</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 16</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'F'   KISWAHILI - 'C'   ENGLISH - 'S'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0576</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 21</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">0</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   GEOGR - 'F'   CHEMISTRY - 'F'   BIOLOGY - 'F'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0577</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 15</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   HISTORY - 'E'   KISWAHILI - 'C'   ENGLISH - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0578</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 13</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'D'   GEOGR - 'E'   ENGLISH - 'D'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0579</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 13</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   HISTORY - 'E'   GEOGR - 'E'   KISWAHILI - 'C'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0580</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 17</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   GEOGR - 'D'   CHEMISTRY - 'F'   BIOLOGY - 'S'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0581</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 16</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   GEOGR - 'D'   CHEMISTRY - 'S'   BIOLOGY - 'S'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0582</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 17</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   PHYSICS - 'E'   CHEMISTRY - 'F'   ADV/MATHS - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0583</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 17</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'F'   GEOGR - 'S'   KISWAHILI - 'D'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0584</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">0</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   HISTORY - 'F'   ENGLISH - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0585</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 10</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">II</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'D'   GEOGR - 'D'   KISWAHILI - 'B'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0586</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 19</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   GEOGR - 'E'   CHEMISTRY - 'F'   BIOLOGY - 'F'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0587</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 12</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">II</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'E'   GEOGR - 'D'   KISWAHILI - 'C'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0588</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 16</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">PHYSICS - 'S'   CHEMISTRY - 'S'   BIOLOGY - 'D'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0589</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">ABS</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">PHYSICS - 'X'   CHEMISTRY - 'X'   ADV/MATHS - 'X'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0590</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 21</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">0</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   PHYSICS - 'F'   CHEMISTRY - 'F'   BIOLOGY - 'F'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0591</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 21</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">0</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   PHYSICS - 'F'   CHEMISTRY - 'F'   BIOLOGY - 'F'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0592</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 12</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">II</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   HISTORY - 'D'   KISWAHILI - 'C'   ENGLISH - 'E'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0593</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> -</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   GEOGR - 'E'   CHEMISTRY - 'F'   BIOLOGY - 'X'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0594</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 16</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   GEOGR - 'D'   CHEMISTRY - 'F'   BIOLOGY - 'E'   BAM - 'F'   </p></font></td></tr>
# <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0595</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">M</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 21</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">0</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   GEOGR - 'F'   CHEMISTRY - 'F'   BIOLOGY - 'F'   BAM - 'F'   </p></font></td></tr>

# %% [markdown]
# The soup object allows you to extract interesting information about the website you're scraping such as getting the title of the page as shown below.
# You can view the html of the webpage by right-clicking anywhere on the webpage and selecting "Inspect." This above see shows what the result looks like.

# %%
# Get the title
title = soup.title
print(title)               #for this page it has no title as you can see on the above html codes
# Out:
# None

# %% [markdown]
# You can use the find_all() method of soup to extract useful html tags within a webpage.
# Examples of useful tags include < a > for hyperlinks, < table > for tables, < tr > for table rows, < th > for table headers, and < td > for table cells.
# The code below shows how to extract all the rows within the table in a webpage. for our case we have only one table.

# %%
rows = soup.find_all('tr')
print(rows[:5])
# Out:
# [<tr><td valign="MIDDLE" width="6%">
# <p align="CENTER"><b><font face="Courier" size="2">CNO</font></b></p></td></tr>, <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0501</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 18</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'F'   GEOGR - 'E'   CHEMISTRY - 'F'   BIOLOGY - 'S'   BAM - 'F'   </p></font></td></tr>, <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0502</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 16</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">III</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'F'   KISWAHILI - 'C'   ENGLISH - 'S'   </p></font></td></tr>, <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0503</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 9</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">I</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'E'   HISTORY - 'D'   KISWAHILI - 'B'   ENGLISH - 'C'   </p></font></td></tr>, <tr><td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER">P0104/0504</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">F</p></font></td>
# <td valign="MIDDLE" width="6%">
# <font face="Arial" size="1"><p align="CENTER"> 18</p></font></td>
# <td valign="MIDDLE" width="4%">
# <font face="Arial" size="1"><p align="CENTER">IV</p></font></td>
# <td valign="MIDDLE" width="58%">
# <font face="Arial" size="1"><p align="LEFT">G/STUDIES - 'S'   HISTORY - 'F'   GEOGR - 'S'   ENGLISH - 'E'   </p></font></td></tr>]

# %% [markdown]
# The output above shows that each row is printed with html tags embedded in each row. This is not what you want. You can use remove the html tags using Beautiful Soup or regular expressions.
#
# The easiest way to remove html tags is to use Beautiful Soup, and it takes just one line of code to do this. Pass the string of interest into BeautifulSoup() and use the get_text() method to extract the text without html tags.

# %%
#finding columns in each row
cols= []
for row in rows:
    cells = row.find_all('td')
    cleantext = BeautifulSoup(str_cells, "lxml").get_text()
    cols.append(cleantext)
print(cols[:5])
# Out:
# ["[\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - 'C'   ENGLISH - 'D'   ]", "[\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - 'C'   ENGLISH - 'D'   ]", "[\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - 'C'   ENGLISH - 'D'   ]", "[\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - 'C'   ENGLISH - 'D'   ]", "[\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - 'C'   ENGLISH - 'D'   ]"]

# %% [markdown]
# The next step is to convert the list into a dataframe and get a quick view of the first 10 rows using Pandas.

# %%
dataframe = pd.DataFrame(cols)
dataframe.head(10)
# Out:
#                                                    0
# 0  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 1  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 2  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 3  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 4  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 5  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 6  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 7  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 8  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 9  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...

# %% [markdown]
# okey lets do the same for all the schools we have saved their html files

# %%
list_rows = []
for i in range(0,2):    
    stri = '%02d' % i
    filetoread="files/school"+ stri + '.html'
    print("FTW", filetoread)
    with open(filetoread) as fdr:
        data = fdr.read()
    soup = BeautifulSoup(data, 'html.parser')
    rows = soup.find_all('tr')
    schoolNames=soup.select("h3")[0].text

    
    for row in rows:
        cells = row.find_all('td')
        cleantext = BeautifulSoup(str_cells, "lxml").get_text()
        list_rows.append(cleantext)
     
    df = pd.DataFrame(list_rows)
    print(df)
# Out:
# FTW files/school00.html
#                                                     0
# 0   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 1   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 2   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 3   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 4   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 5   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 6   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 7   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 8   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 9   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 10  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 11  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 12  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 13  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 14  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 15  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 16  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 17  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 18  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 19  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 20  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 21  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 22  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 23  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 24  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 25  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 26  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 27  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 28  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 29  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# ..                                                ...
# 66  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 67  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 68  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 69  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 70  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 71  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 72  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 73  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 74  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 75  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 76  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 77  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 78  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 79  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 80  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 81  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 82  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 83  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 84  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 85  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 86  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 87  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 88  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 89  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 90  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 91  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 92  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 93  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 94  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 95  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
#
# [96 rows x 1 columns]
# FTW files/school01.html
#                                                      0
# 0    [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 1    [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 2    [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 3    [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 4    [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 5    [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 6    [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 7    [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 8    [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 9    [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 10   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 11   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 12   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 13   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 14   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 15   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 16   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 17   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 18   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 19   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 20   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 21   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 22   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 23   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 24   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 25   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 26   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 27   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 28   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 29   [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# ..                                                 ...
# 307  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 308  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 309  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 310  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 311  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 312  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 313  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 314  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 315  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 316  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 317  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 318  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 319  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 320  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 321  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 322  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 323  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 324  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 325  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 326  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 327  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 328  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 329  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 330  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 331  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 332  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 333  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 334  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 335  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
# 336  [\nP0110/0741, \nF, \n 13, \nIII, \nG/STUDIES ...
#
# [337 rows x 1 columns]

# %% [markdown]
# ## 3. Data Manipulation and Cleaning
#
# Ok so now lets dive in and get the data in the format required.
# The dataframe is not in the format we want. To clean it up, you should split the "0" column into multiple columns at the comma position. This is accomplished by using the str.split() method.

# %%
df1 = df[0].str.split(',', expand=True)
df1.head(10)
# Out:
#                0     1       2       3                                                  4
# 0  [\nP0110/0741   \nF   \n 13   \nIII   \nG/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI...
# 1  [\nP0110/0741   \nF   \n 13   \nIII   \nG/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI...
# 2  [\nP0110/0741   \nF   \n 13   \nIII   \nG/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI...
# 3  [\nP0110/0741   \nF   \n 13   \nIII   \nG/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI...
# 4  [\nP0110/0741   \nF   \n 13   \nIII   \nG/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI...
# 5  [\nP0110/0741   \nF   \n 13   \nIII   \nG/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI...
# 6  [\nP0110/0741   \nF   \n 13   \nIII   \nG/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI...
# 7  [\nP0110/0741   \nF   \n 13   \nIII   \nG/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI...
# 8  [\nP0110/0741   \nF   \n 13   \nIII   \nG/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI...
# 9  [\nP0110/0741   \nF   \n 13   \nIII   \nG/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI...

# %% [markdown]
# This looks much better, but there is still work to do. The dataframe has unwanted square brackets surrounding each row. You can use the strip() method to remove the opening square bracket on column "0."

# %%
df1[0] = df1[0].str.strip('[')    #removing the [ in column 1
df1[4] = df1[4].str.strip('[')    #removing the [ in the last column 
df1[0] = df1[0].str.strip('\n') 
df1[1] = df1[1].str.strip(' \n') 
df1[2] = df1[2].str.strip('\n ') 
df1[3] = df1[3].str.strip(' \n')
df1[4] = df1[4].str.strip(' \n') #removing the \n in all the columns
df1.head(10)
# Out:
#             0  1   2    3                                                  4
# 0  P0110/0741  F  13  III  G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - ...
# 1  P0110/0741  F  13  III  G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - ...
# 2  P0110/0741  F  13  III  G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - ...
# 3  P0110/0741  F  13  III  G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - ...
# 4  P0110/0741  F  13  III  G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - ...
# 5  P0110/0741  F  13  III  G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - ...
# 6  P0110/0741  F  13  III  G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - ...
# 7  P0110/0741  F  13  III  G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - ...
# 8  P0110/0741  F  13  III  G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - ...
# 9  P0110/0741  F  13  III  G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - ...

# %% [markdown]
# ![](images/goodreads3.png)

# %% [markdown]
# The table is missing table headers. You can use the find_all() method to get the table headers. The html tag fpr table header is usually <th> but for our case there is no defined table header we will just right the list of the columns name

# %%
df1.columns = ['index' , 'sex', 'aggr','division','subjects']
df1.head()
# Out:
#         index sex aggr division                                           subjects
# 0  P0110/0741   F   13      III  G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - ...
# 1  P0110/0741   F   13      III  G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - ...
# 2  P0110/0741   F   13      III  G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - ...
# 3  P0110/0741   F   13      III  G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - ...
# 4  P0110/0741   F   13      III  G/STUDIES - 'E'   HISTORY - 'S'   KISWAHILI - ...

# %%
df1.info()
df1.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 337 entries, 0 to 336
# Data columns (total 5 columns):
# index       337 non-null object
# sex         337 non-null object
# aggr        337 non-null object
# division    337 non-null object
# subjects    337 non-null object
# dtypes: object(5)
# memory usage: 13.2+ KB
# (337, 5)

# %% [markdown]
# Now we can save the data for future uses.

# %%
df.to_csv("files/student_results.csv", index=False, header=True)

# %% [markdown]
# ### Exercise
# Your job is to write the code to get the list of ten schools code for example Bwiru Boys' Center is P0104 and save in a list called school_code.

# %% [markdown]
# Use this link https://onlinesys.necta.go.tz/results/2019/acsee/acsee.htm to get list of the school codes

# %%
## write you code here

## Get the html file first and save it as homepage.html at the folder called results

####################### write you code here


## Create Beautiful soup object
school_url= []
filetoread="files/homepage.html"
####################### write you code here


##Create a list of url for the first 100 schools

####################### write you code here
# Out:
# FTW files/homepage.html
# FTW files/homepage.html
# ['results/p0101.htm', 'results/p0104.htm', 'results/p0110.htm', 'results/p0112.htm', 'results/p0116.htm', 'results/p0119.htm', 'results/p0123.htm', 'results/p0129.htm', 'results/p0132.htm', 'results/p0133.htm']

# %% [markdown]
# ## 4. Set up a pipeline for fetching and parsing
#
# Ok lets get back to the fetching...

# %%
urlStart = "https://onlinesys.necta.go.tz/results/2019/acsee/"
for i in range(0,20):    
    stuff=requests.get(urlStart+school_url[i])
    filetowrite = school_url[i]
    print("FTW", filetowrite)
    f = open(filetowrite,'w',encoding="utf-8")
    f.write(stuff.text)
    f.close()
# Out:
# FTW results/p0101.htm
# FTW results/p0104.htm

# %% [markdown]
# We have now saved html files for each school according to there school codes

# %% [markdown]
# ### Note
#
# Now we have used Beautiful soup to scrape content from NECTA website.
#
# Whether or not you intend to use data scraping in your work, it’s advisable to still educate yourself on the subject, as it is most likely to become even more important in the next few years.
#
# There are now data scraping AI on the market that can use machine learning to keep on getting better at recognising inputs which only humans have traditionally been able to interpret – like images
