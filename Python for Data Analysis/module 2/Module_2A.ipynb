# %% [markdown]
# # <img style="float: left; padding-right: 100px; width: 300px" src="../image/logo.png">AI4SG Bootcamp:
#
#
#
# ## Introduction to Pandas for Data processing and Analysis
#
#
# **Authors:** Faustine
#
#
# ---

# %% [markdown]
# To use Panda first load the panda library

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Introduction to Pandas
#
# pandas the most powerful and flexible python library for data analysis and modelling. It contains *data structures* and *data manipulation* tools designed to make data cleaning and analysis fast and easy in Python. Pandas adopts significant
# parts of NumPy’s idiomatic style of array-based computing, especially array-based
# functions and a preference for data processing without for loops. While pandas adopts many coding idioms from NumPy, the biggest difference is that:pandas is designed for working with tabular or heterogeneous data where NumPy, by con‐ trast, is best suited for working with homogeneous numerical array data

# %% [markdown]
# ### Pandas  data structure
# Pandas provides two fundamental data objects, for 1D (``Series``) and 2D data (``DataFrame``).
#
# A ``Series`` is a one-dimensional array-like object containing a sequence of values (of
# similar types to NumPy types) and an associated array of data labels, called its index.
# The simplest Series is formed from only an array of data:

# %%
s = pd.Series([0.1, 0.2, 0.3, 0.4])
s
# Out:
# 0    0.1
# 1    0.2
# 2    0.3
# 3    0.4
# dtype: float64

# %% [markdown]
# The series also has an index, which by default is the numbers 0* through *N - 1 (but no .columns):

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# You can access the underlying numpy array representation with the `.values` attribute:

# %%
s.values
# Out:
# array([0.1, 0.2, 0.3, 0.4])

# %% [markdown]
# A `DataFrame` is a **tablular data structure** (multi-dimensional object to hold labeled data) comprised of rows and columns, akin to a spreadsheet, database table, or R's data.frame object. You can think of it as multiple Series object which share the same index.
#
# For the examples here, we are going to create a small DataFrame with some data about a few countries. When creating a DataFrame manually, a common way to do this is from dictionary of arrays or lists:

# %%
data = {'Region': ['Mwanza', 'Dar es salaam', 'Arusha', 'Mbeya', 'Dodoma'],
        'population': [706543, 4364541, 416442, 385279, 213636],
        'area': [9467, 1590, 37576, 35954, 2576]}
cities = pd.DataFrame(data)
cities
# Out:
#           Region  population   area
# 0         Mwanza      706543   9467
# 1  Dar es salaam     4364541   1590
# 2         Arusha      416442  37576
# 3          Mbeya      385279  35954
# 4         Dodoma      213636   2576

# %% [markdown]
# The DataFrame has a built-in concept of named rows and columns, the **`index`** and **`columns`** attributes:

# %%
cities.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
cities.columns
# Out:
# Index(['Region', 'population', 'area (km square)'], dtype='object')

# %% [markdown]
# To check the data types of the different columns:

# %%
cities.dtypes
# Out:
# Region              object
# population           int64
# area (km square)     int64
# dtype: object

# %% [markdown]
# A DataFrame has also a `values` attribute, but attention: when you have heterogeneous data, all values will be upcasted:

# %%
cities.values
# Out:
# array([['Mwanza', 706543, 9467],
#        ['Dar es salaam', 4364541, 1590],
#        ['Arusha', 416442, 37576],
#        ['Mbeya', 385279, 35954],
#        ['Dodoma', 213636, 2576]], dtype=object)

# %% [markdown]
# ## 2. Pandas IO Tools  and basic operations
#
# A wide range of [input/output formats](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html#io-perf) are natively supported by pandas:
#
# * CSV, text
# * SQL database
# * Excel
# * HDF5
# * json
# * html
# * pickle
# * sas, stata
# * Parquet
# * ...

# %% [markdown]
# ### Reading from  CSV file

# %%
data = pd.read_csv('data/primary.csv')

# %% [markdown]
# Exploration of the Series and DataFrame is essential (check out what you're dealing with).

# %%
# Let view the first few rows 
data.head()
# Out:
#    REGION      DISTRICT     MALE   FEMALE
# 0  ARUSHA  ARUSHA RURAL  32475.0  33698.0
# 1  ARUSHA  ARUSHA URBAN  36315.0  36993.0
# 2  ARUSHA        KARATU  23303.0  23181.0
# 3  ARUSHA       LONGIDO  10584.0   9045.0
# 4  ARUSHA          MERU  33854.0  34171.0

# %%
# View Last 6 rows
data.tail(6)
# Out:
#     REGION       DISTRICT     MALE   FEMALE
# 157  TANGA  KOROGWE URBAN   6240.0   6057.0
# 158  TANGA        LUSHOTO  69395.0  70238.0
# 159  TANGA         MKINGA  12799.0  12568.0
# 160  TANGA         MUHEZA  19672.0  19650.0
# 161  TANGA        PANGANI   4903.0   4925.0
# 162  TANGA    TANGA URBAN  26555.0  26487.0

# %%
# List all the columns in the DataFrame
data.columns
# Out:
# Index(['REGION', 'DISTRICT', 'MALE', 'FEMALE'], dtype='object')

# %%
# We can use the len function again here to see how many rows there are in the dataframe: 163
len(data)
# Out:
# 163

# %%
# How big is this dataframe (rows, columns)
data.shape
# Out:
# (163, 4)

# %% [markdown]
# Notice that read_csv automatically considered the first row in the file to be a header row.
# We can override default behavior by customizing some the arguments, like header, names or index_col.

# %% [markdown]
# <div class="alert alert-success">
#     <b>Activity 1</b>: Load the university enrollment data  as a pandas data frame and inspect the first 5 rows. How many row does the data set contain?
# </div>

# %% [markdown]
# ###  Adding and Droping column
# Let us add another column to the primary dataframe. Suppose we want to add total enrollment column

# %%
data['TOTAL']=data['MALE']+ data["FEMALE"]

# %%
data.head()
# Out:
#    REGION      DISTRICT     MALE   FEMALE    TOTAL
# 0  ARUSHA  ARUSHA RURAL  32475.0  33698.0  66173.0
# 1  ARUSHA  ARUSHA URBAN  36315.0  36993.0  73308.0
# 2  ARUSHA        KARATU  23303.0  23181.0  46484.0
# 3  ARUSHA       LONGIDO  10584.0   9045.0  19629.0
# 4  ARUSHA          MERU  33854.0  34171.0  68025.0

# %% [markdown]
# It clear from the above result we can perform arthmetic operation on pandas dataframe.

# %% [markdown]
# ### Dropping Column
#
# We can  delete column in panda dataframe. Let us delete the TOTAL column in primary enrollment dataframe.

# %%
data.drop('TOTAL', axis=1, inplace=True)
data.head()
# Out:
#    REGION      DISTRICT     MALE   FEMALE
# 0  ARUSHA  ARUSHA RURAL  32475.0  33698.0
# 1  ARUSHA  ARUSHA URBAN  36315.0  36993.0
# 2  ARUSHA        KARATU  23303.0  23181.0
# 3  ARUSHA       LONGIDO  10584.0   9045.0
# 4  ARUSHA          MERU  33854.0  34171.0

# %% [markdown]
# #### Note:
#  1. **axis=1** denotes that we are referring to a column, not a row
#  2. **inplace=True** means that the changes are saved to the df right away

# %% [markdown]
# <div class="alert alert-success">
#     <b>Activity 2</b>: Add Total enrollment in university dataframe. Drop the Total you created and gender columns in university dataset
# </div>
#
#
# **Hint**: To delete multiple column use *dataframe.drop(['Column_name1', 'Column_name2'], axis=1)*.

# %% [markdown]
# ### Data selection and slicing

# %% [markdown]
# Selecting a single column - returns a 'series'

# %%
data.REGION
# You can aslo use data['REGION']
# Out:
# 0             ARUSHA
# 1             ARUSHA
# 2             ARUSHA
# 3             ARUSHA
# 4             ARUSHA
# 5             ARUSHA
# 6             ARUSHA
# 7      DAR ES SALAAM
# 8      DAR ES SALAAM
# 9      DAR ES SALAAM
# 10            DODOMA
# 11            DODOMA
# 12            DODOMA
# 13            DODOMA
# 14            DODOMA
# 15            DODOMA
# 16            DODOMA
# 17             GEITA
# 18             GEITA
# 19             GEITA
# 20             GEITA
# 21             GEITA
# 22             GEITA
# 23            IRINGA
# 24            IRINGA
# 25            IRINGA
# 26            IRINGA
# 27            KAGERA
# 28            KAGERA
# 29            KAGERA
#            ...
# 133        SHINYANGA
# 134           SIMIYU
# 135           SIMIYU
# 136           SIMIYU
# 137           SIMIYU
# 138           SIMIYU
# 139           SIMIYU
# 140          SINGIDA
# 141          SINGIDA
# 142          SINGIDA
# 143          SINGIDA
# 144          SINGIDA
# 145          SINGIDA
# 146           TABORA
# 147           TABORA
# 148           TABORA
# 149           TABORA
# 150           TABORA
# 151           TABORA
# 152           TABORA
# 153            TANGA
# 154            TANGA
# 155            TANGA
# 156            TANGA
# 157            TANGA
# 158            TANGA
# 159            TANGA
# 160            TANGA
# 161            TANGA
# 162            TANGA
# Name: REGION, Length: 163, dtype: object

# %%
# To select column as data frame
data[['DISTRICT']]
# Out:
#           DISTRICT
# 0     ARUSHA RURAL
# 1     ARUSHA URBAN
# 2           KARATU
# 3          LONGIDO
# 4             MERU
# 5          MONDULI
# 6       NGORONGORO
# 7            ILALA
# 8        KINONDONI
# 9           TEMEKE
# 10            BAHI
# 11        CHAMWINO
# 12          CHEMBA
# 13    DODOMA URBAN
# 14          KONDOA
# 15          KONGWA
# 16         MPWAPWA
# 17         BUKOMBE
# 18           CHATO
# 19           GEITA
# 20     GEITA URBAN
# 21          MBOGWE
# 22     NYANG'HWALE
# 23    IRINGA RURAL
# 24    IRINGA URBAN
# 25          KILOLO
# 26         MUFINDI
# 27      BIHARAMULO
# 28    BUKOBA RURAL
# 29    BUKOBA URBAN
# ..             ...
# 133         USHETU
# 134  BARIADI RURAL
# 135  BARIADI URBAN
# 136         BUSEGA
# 137        ITILIMA
# 138          MASWA
# 139          MEATU
# 140         IKUNGI
# 141         IRAMBA
# 142        MANYONI
# 143        MKALAMA
# 144  SINGIDA RURAL
# 145  SINGIDA URBAN
# 146         IGUNGA
# 147         KALIUA
# 148          NZEGA
# 149        SIKONGE
# 150   TABORA URBAN
# 151         URAMBO
# 152           UYUI
# 153        BUMBULI
# 154        HANDENI
# 155        KILINDI
# 156  KOROGWE RURAL
# 157  KOROGWE URBAN
# 158        LUSHOTO
# 159         MKINGA
# 160         MUHEZA
# 161        PANGANI
# 162    TANGA URBAN
#
# [163 rows x 1 columns]

# %% [markdown]
#  Selecting multiple columns - returns a dataframe

# %%
data[['REGION','DISTRICT']]
# Out:
#             REGION       DISTRICT
# 0           ARUSHA   ARUSHA RURAL
# 1           ARUSHA   ARUSHA URBAN
# 2           ARUSHA         KARATU
# 3           ARUSHA        LONGIDO
# 4           ARUSHA           MERU
# 5           ARUSHA        MONDULI
# 6           ARUSHA     NGORONGORO
# 7    DAR ES SALAAM          ILALA
# 8    DAR ES SALAAM      KINONDONI
# 9    DAR ES SALAAM         TEMEKE
# 10          DODOMA           BAHI
# 11          DODOMA       CHAMWINO
# 12          DODOMA         CHEMBA
# 13          DODOMA   DODOMA URBAN
# 14          DODOMA         KONDOA
# 15          DODOMA         KONGWA
# 16          DODOMA        MPWAPWA
# 17           GEITA        BUKOMBE
# 18           GEITA          CHATO
# 19           GEITA          GEITA
# 20           GEITA    GEITA URBAN
# 21           GEITA         MBOGWE
# 22           GEITA    NYANG'HWALE
# 23          IRINGA   IRINGA RURAL
# 24          IRINGA   IRINGA URBAN
# 25          IRINGA         KILOLO
# 26          IRINGA        MUFINDI
# 27          KAGERA     BIHARAMULO
# 28          KAGERA   BUKOBA RURAL
# 29          KAGERA   BUKOBA URBAN
# ..             ...            ...
# 133      SHINYANGA         USHETU
# 134         SIMIYU  BARIADI RURAL
# 135         SIMIYU  BARIADI URBAN
# 136         SIMIYU         BUSEGA
# 137         SIMIYU        ITILIMA
# 138         SIMIYU          MASWA
# 139         SIMIYU          MEATU
# 140        SINGIDA         IKUNGI
# 141        SINGIDA         IRAMBA
# 142        SINGIDA        MANYONI
# 143        SINGIDA        MKALAMA
# 144        SINGIDA  SINGIDA RURAL
# 145        SINGIDA  SINGIDA URBAN
# 146         TABORA         IGUNGA
# 147         TABORA         KALIUA
# 148         TABORA          NZEGA
# 149         TABORA        SIKONGE
# 150         TABORA   TABORA URBAN
# 151         TABORA         URAMBO
# 152         TABORA           UYUI
# 153          TANGA        BUMBULI
# 154          TANGA        HANDENI
# 155          TANGA        KILINDI
# 156          TANGA  KOROGWE RURAL
# 157          TANGA  KOROGWE URBAN
# 158          TANGA        LUSHOTO
# 159          TANGA         MKINGA
# 160          TANGA         MUHEZA
# 161          TANGA        PANGANI
# 162          TANGA    TANGA URBAN
#
# [163 rows x 2 columns]

# %% [markdown]
# Selecting rows by number

# %%
data[15:20]
# Out:
#     REGION DISTRICT      MALE    FEMALE
# 15  DODOMA   KONGWA   27169.0   30264.0
# 16  DODOMA  MPWAPWA   32176.0   31646.0
# 17   GEITA  BUKOMBE   39490.0   40178.0
# 18   GEITA    CHATO   39377.0   38393.0
# 19   GEITA    GEITA  115698.0  116328.0

# %%
# Try  data[:8] and data[100:]
data[:8]
# Out:
#           REGION      DISTRICT     MALE   FEMALE
# 0         ARUSHA  ARUSHA RURAL  32475.0  33698.0
# 1         ARUSHA  ARUSHA URBAN  36315.0  36993.0
# 2         ARUSHA        KARATU  23303.0  23181.0
# 3         ARUSHA       LONGIDO  10584.0   9045.0
# 4         ARUSHA          MERU  33854.0  34171.0
# 5         ARUSHA       MONDULI  13689.0  12888.0
# 6         ARUSHA    NGORONGORO  16017.0  12162.0
# 7  DAR ES SALAAM         ILALA  73129.0  78309.0

# %% [markdown]
# ### Indexing
# Pandas allows us to use position based indexing implemented with iloc
# `.loc` for label-based indexing
# and loc
# `.iloc` for positional indexing

# %% [markdown]
# We have mostly worked with DataFrames with the default *0, 1, 2, ... N* row labels (except for the time series data). But, we can also set one of the columns as the index.
#
# Setting the index to the region names:

# %%
data = data.set_index('REGION')
data.head()
# Out:
#             DISTRICT     MALE   FEMALE
# REGION
# ARUSHA  ARUSHA RURAL  32475.0  33698.0
# ARUSHA  ARUSHA URBAN  36315.0  36993.0
# ARUSHA        KARATU  23303.0  23181.0
# ARUSHA       LONGIDO  10584.0   9045.0
# ARUSHA          MERU  33854.0  34171.0

# %% [markdown]
# Reversing this operation, is `reset_index`:

# %%
data=data.reset_index('REGION')
data.head()
# Out:
#    REGION      DISTRICT     MALE   FEMALE
# 0  ARUSHA  ARUSHA RURAL  32475.0  33698.0
# 1  ARUSHA  ARUSHA URBAN  36315.0  36993.0
# 2  ARUSHA        KARATU  23303.0  23181.0
# 3  ARUSHA       LONGIDO  10584.0   9045.0
# 4  ARUSHA          MERU  33854.0  34171.0

# %% [markdown]
# ### Selecting data based on the index
#
# <div class="alert alert-warning" style="font-size:120%">
# <b>ATTENTION!</b>: <br><br>
#
# One of pandas' basic features is the labeling of rows and columns, but this makes indexing also a bit more complex compared to numpy. <br><br> We now have to distuinguish between:
#
# * selection by **label** (using the row and column names)
# * selection by **position** (using integers)
#
# </div>

# %% [markdown]
# When using `[]` like above, you can only select from one axis at once (rows or columns, not both). For more advanced indexing, you have some extra attributes:
#
# * `loc`: selection by label
# * `iloc`: selection by position
#
# Both `loc` and `iloc` use the following pattern: `df.loc[ <selection of the rows> , <selection of the columns> ]`.
#
# This 'selection of the rows / columns' can be: a single label, a list of labels, a slice or a boolean mask.

# %% [markdown]
# Selecting a single element

# %% [markdown]
# Consider cities dataframe

# %%
cities = cities.set_index('Region')

# %%
cities.loc['Mwanza', 'population']
# Out:
# 706543

# %% [markdown]
# But the row or column indexer can also be a list, slice, boolean array (see next section), ..

# %%
cities.loc['Mwanza':'Arusha', ['area', 'population']]
# Out:
#                 area  population
# Region
# Mwanza          9467      706543
# Dar es salaam   1590     4364541
# Arusha         37576      416442

# %% [markdown]
# <div class="alert alert-danger">
# <b>NOTE</b>:
#
# * Unlike slicing in numpy, the end label is **included**!
#
# </div>

# %% [markdown]
# Selecting by position with `iloc` works similar as **indexing numpy arrays**:

# %%
cities.iloc[0:2,1:3]
# Out:
#                area
# Region
# Mwanza         9467
# Dar es salaam  1590

# %% [markdown]
# The different indexing methods can also be used to **assign data**:

# %%
cities2 = cities.copy()
cities2.loc['Mwanza':'Arusha', 'population'] = 10000
cities2
# Out:
#                population   area
# Region
# Mwanza              10000   9467
# Dar es salaam       10000   1590
# Arusha              10000  37576
# Mbeya              385279  35954
# Dodoma             213636   2576

# %% [markdown]
# To slice a specific column using label indexing

# %%
# And here is how to slice a column:
data.loc[: , "REGION"]
# Out:
# 0             ARUSHA
# 1             ARUSHA
# 2             ARUSHA
# 3             ARUSHA
# 4             ARUSHA
# 5             ARUSHA
# 6             ARUSHA
# 7      DAR ES SALAAM
# 8      DAR ES SALAAM
# 9      DAR ES SALAAM
# 10            DODOMA
# 11            DODOMA
# 12            DODOMA
# 13            DODOMA
# 14            DODOMA
# 15            DODOMA
# 16            DODOMA
# 17             GEITA
# 18             GEITA
# 19             GEITA
# 20             GEITA
# 21             GEITA
# 22             GEITA
# 23            IRINGA
# 24            IRINGA
# 25            IRINGA
# 26            IRINGA
# 27            KAGERA
# 28            KAGERA
# 29            KAGERA
#            ...
# 133        SHINYANGA
# 134           SIMIYU
# 135           SIMIYU
# 136           SIMIYU
# 137           SIMIYU
# 138           SIMIYU
# 139           SIMIYU
# 140          SINGIDA
# 141          SINGIDA
# 142          SINGIDA
# 143          SINGIDA
# 144          SINGIDA
# 145          SINGIDA
# 146           TABORA
# 147           TABORA
# 148           TABORA
# 149           TABORA
# 150           TABORA
# 151           TABORA
# 152           TABORA
# 153            TANGA
# 154            TANGA
# 155            TANGA
# 156            TANGA
# 157            TANGA
# 158            TANGA
# 159            TANGA
# 160            TANGA
# 161            TANGA
# 162            TANGA
# Name: REGION, Length: 163, dtype: object

# %% [markdown]
# We can also use postion indexing

# %%
data.iloc[:,0]
# Out:
# 0             ARUSHA
# 1             ARUSHA
# 2             ARUSHA
# 3             ARUSHA
# 4             ARUSHA
# 5             ARUSHA
# 6             ARUSHA
# 7      DAR ES SALAAM
# 8      DAR ES SALAAM
# 9      DAR ES SALAAM
# 10            DODOMA
# 11            DODOMA
# 12            DODOMA
# 13            DODOMA
# 14            DODOMA
# 15            DODOMA
# 16            DODOMA
# 17             GEITA
# 18             GEITA
# 19             GEITA
# 20             GEITA
# 21             GEITA
# 22             GEITA
# 23            IRINGA
# 24            IRINGA
# 25            IRINGA
# 26            IRINGA
# 27            KAGERA
# 28            KAGERA
# 29            KAGERA
#            ...
# 133        SHINYANGA
# 134           SIMIYU
# 135           SIMIYU
# 136           SIMIYU
# 137           SIMIYU
# 138           SIMIYU
# 139           SIMIYU
# 140          SINGIDA
# 141          SINGIDA
# 142          SINGIDA
# 143          SINGIDA
# 144          SINGIDA
# 145          SINGIDA
# 146           TABORA
# 147           TABORA
# 148           TABORA
# 149           TABORA
# 150           TABORA
# 151           TABORA
# 152           TABORA
# 153            TANGA
# 154            TANGA
# 155            TANGA
# 156            TANGA
# 157            TANGA
# 158            TANGA
# 159            TANGA
# 160            TANGA
# 161            TANGA
# 162            TANGA
# Name: REGION, Length: 163, dtype: object

# %% [markdown]
# To extract only a row you would do the inverse:

# %%
data.iloc[2,:]
# Out:
# REGION      ARUSHA
# DISTRICT    KARATU
# MALE         23303
# FEMALE       23181
# Name: 2, dtype: object

# %% [markdown]
# To select range of row and column

# %%
##Select first four rows(including header) and first three column (including SN)
data.iloc[0:3,0:2]
# Out:
#    REGION      DISTRICT
# 0  ARUSHA  ARUSHA RURAL
# 1  ARUSHA  ARUSHA URBAN
# 2  ARUSHA        KARATU

# %% [markdown]
# Select only the specified range of column

# %%
data.iloc[:,1:3]
# Out:
#           DISTRICT      MALE
# 0     ARUSHA RURAL   32475.0
# 1     ARUSHA URBAN   36315.0
# 2           KARATU   23303.0
# 3          LONGIDO   10584.0
# 4             MERU   33854.0
# 5          MONDULI   13689.0
# 6       NGORONGORO   16017.0
# 7            ILALA   73129.0
# 8        KINONDONI   91554.0
# 9           TEMEKE   85118.0
# 10            BAHI   15672.0
# 11        CHAMWINO   26483.0
# 12          CHEMBA       NaN
# 13    DODOMA URBAN   35137.0
# 14          KONDOA   48859.0
# 15          KONGWA   27169.0
# 16         MPWAPWA   32176.0
# 17         BUKOMBE   39490.0
# 18           CHATO   39377.0
# 19           GEITA  115698.0
# 20     GEITA URBAN       NaN
# 21          MBOGWE       NaN
# 22     NYANG'HWALE       NaN
# 23    IRINGA RURAL   28608.0
# 24    IRINGA URBAN   13115.0
# 25          KILOLO   29161.0
# 26         MUFINDI   32996.0
# 27      BIHARAMULO   20620.0
# 28    BUKOBA RURAL   27577.0
# 29    BUKOBA URBAN   10377.0
# ..             ...       ...
# 133         USHETU       NaN
# 134  BARIADI RURAL   75089.0
# 135  BARIADI URBAN       NaN
# 136         BUSEGA       NaN
# 137        ITILIMA       NaN
# 138          MASWA   31095.0
# 139          MEATU   30721.0
# 140         IKUNGI       NaN
# 141         IRAMBA   41539.0
# 142        MANYONI   25158.0
# 143        MKALAMA       NaN
# 144  SINGIDA RURAL   44844.0
# 145  SINGIDA URBAN   13385.0
# 146         IGUNGA   35226.0
# 147         KALIUA       NaN
# 148          NZEGA   51661.0
# 149        SIKONGE   15929.0
# 150   TABORA URBAN   22901.0
# 151         URAMBO   47703.0
# 152           UYUI   38260.0
# 153        BUMBULI       NaN
# 154        HANDENI   35554.0
# 155        KILINDI   39676.0
# 156  KOROGWE RURAL   25306.0
# 157  KOROGWE URBAN    6240.0
# 158        LUSHOTO   69395.0
# 159         MKINGA   12799.0
# 160         MUHEZA   19672.0
# 161        PANGANI    4903.0
# 162    TANGA URBAN   26555.0
#
# [163 rows x 2 columns]

# %% [markdown]
# To select  different columns

# %%
data.iloc[:,[0, 3]]
# Out:
#             REGION    FEMALE
# 0           ARUSHA   33698.0
# 1           ARUSHA   36993.0
# 2           ARUSHA   23181.0
# 3           ARUSHA    9045.0
# 4           ARUSHA   34171.0
# 5           ARUSHA   12888.0
# 6           ARUSHA   12162.0
# 7    DAR ES SALAAM   78309.0
# 8    DAR ES SALAAM   93921.0
# 9    DAR ES SALAAM   88813.0
# 10          DODOMA   15967.0
# 11          DODOMA   28264.0
# 12          DODOMA       NaN
# 13          DODOMA   36806.0
# 14          DODOMA   55869.0
# 15          DODOMA   30264.0
# 16          DODOMA   31646.0
# 17           GEITA   40178.0
# 18           GEITA   38393.0
# 19           GEITA  116328.0
# 20           GEITA       NaN
# 21           GEITA       NaN
# 22           GEITA       NaN
# 23          IRINGA   28990.0
# 24          IRINGA   13449.0
# 25          IRINGA   30316.0
# 26          IRINGA   34659.0
# 27          KAGERA   20865.0
# 28          KAGERA   28264.0
# 29          KAGERA   10654.0
# ..             ...       ...
# 133      SHINYANGA       NaN
# 134         SIMIYU   79153.0
# 135         SIMIYU       NaN
# 136         SIMIYU       NaN
# 137         SIMIYU       NaN
# 138         SIMIYU   33992.0
# 139         SIMIYU   32209.0
# 140        SINGIDA       NaN
# 141        SINGIDA   40906.0
# 142        SINGIDA   24947.0
# 143        SINGIDA       NaN
# 144        SINGIDA   46895.0
# 145        SINGIDA   14007.0
# 146         TABORA   35892.0
# 147         TABORA       NaN
# 148         TABORA   50067.0
# 149         TABORA   15217.0
# 150         TABORA   23134.0
# 151         TABORA   45939.0
# 152         TABORA   36122.0
# 153          TANGA       NaN
# 154          TANGA   35379.0
# 155          TANGA   40330.0
# 156          TANGA   25000.0
# 157          TANGA    6057.0
# 158          TANGA   70238.0
# 159          TANGA   12568.0
# 160          TANGA   19650.0
# 161          TANGA    4925.0
# 162          TANGA   26487.0
#
# [163 rows x 2 columns]

# %% [markdown]
# <div class="alert alert-success">
#     <b>Activity 3</b>: What happens when you type the code below?
# </div>
#
# 1. `university.loc[[0, 10, 50], :]`
# 2. `university.iloc[0:4, 1:4]`
# 3. `university[0:3]`
# 4. `university[:5]`
# 5. `university[-1:]`

# %% [markdown]
# ### Subsetting Data Using Criteria
#
# Often, you want to select rows based on a certain condition. This can be done with 'boolean indexing' (like a where clause in SQL) and comparable to numpy.
#
# The indexer (or boolean mask) should be 1-dimensional and the same length as the thing being indexed.
#
# For example, we can select all rows that have female higher than 50000.

# %%
data[data.FEMALE > 50000]
# Out:
#             REGION       DISTRICT      MALE    FEMALE
# 7    DAR ES SALAAM          ILALA   73129.0   78309.0
# 8    DAR ES SALAAM      KINONDONI   91554.0   93921.0
# 9    DAR ES SALAAM         TEMEKE   85118.0   88813.0
# 14          DODOMA         KONDOA   48859.0   55869.0
# 19           GEITA          GEITA  115698.0  116328.0
# 30          KAGERA        KARAGWE   58254.0   61567.0
# 33          KAGERA         MULEBA   51631.0   51767.0
# 41          KIGOMA         KASULU   58799.0   60225.0
# 43          KIGOMA   KIGOMA RURAL   55053.0   55122.0
# 80           MBEYA          MBOZI   69952.0   72439.0
# 85        MOROGORO         KILOSA   50740.0   53940.0
# 99          MWANZA           MAGU   58405.0   59754.0
# 102         MWANZA      SENGEREMA   75842.0   75419.0
# 127      SHINYANGA      KAHAMA DC   73794.0   75747.0
# 134         SIMIYU  BARIADI RURAL   75089.0   79153.0
# 148         TABORA          NZEGA   51661.0   50067.0
# 158          TANGA        LUSHOTO   69395.0   70238.0

# %% [markdown]
# Or we can select all rows which are in Arusha

# %%
data[data.REGION == 'ARUSHA']
# Out:
#    REGION      DISTRICT     MALE   FEMALE
# 0  ARUSHA  ARUSHA RURAL  32475.0  33698.0
# 1  ARUSHA  ARUSHA URBAN  36315.0  36993.0
# 2  ARUSHA        KARATU  23303.0  23181.0
# 3  ARUSHA       LONGIDO  10584.0   9045.0
# 4  ARUSHA          MERU  33854.0  34171.0
# 5  ARUSHA       MONDULI  13689.0  12888.0
# 6  ARUSHA    NGORONGORO  16017.0  12162.0

# %% [markdown]
# You can select data based on criteria and choose which column to display. Example let select all districts with male erollment less than 1000.

# %%
data[data.MALE < 10000][['DISTRICT']]
# Out:
#           DISTRICT
# 37    MPANDA URBAN
# 52            SIHA
# 55     LINDI URBAN
# 56          LIWALE
# 60    BABATI URBAN
# 93    MTWARA URBAN
# 111   KIBAHA RURAL
# 114          MAFIA
# 157  KOROGWE URBAN
# 161        PANGANI

# %% [markdown]
# ### Sort Data in Pandas
#
# We can also sort data in pandas. For example let us  sort the dataframe's rows by male, in descending order.

# %%
data.sort_values(by='MALE', ascending=0)
# Out:
#             REGION          DISTRICT      MALE    FEMALE
# 19           GEITA             GEITA  115698.0  116328.0
# 8    DAR ES SALAAM         KINONDONI   91554.0   93921.0
# 9    DAR ES SALAAM            TEMEKE   85118.0   88813.0
# 102         MWANZA         SENGEREMA   75842.0   75419.0
# 134         SIMIYU     BARIADI RURAL   75089.0   79153.0
# 127      SHINYANGA         KAHAMA DC   73794.0   75747.0
# 7    DAR ES SALAAM             ILALA   73129.0   78309.0
# 80           MBEYA             MBOZI   69952.0   72439.0
# 158          TANGA           LUSHOTO   69395.0   70238.0
# 41          KIGOMA            KASULU   58799.0   60225.0
# 99          MWANZA              MAGU   58405.0   59754.0
# 30          KAGERA           KARAGWE   58254.0   61567.0
# 43          KIGOMA      KIGOMA RURAL   55053.0   55122.0
# 148         TABORA             NZEGA   51661.0   50067.0
# 33          KAGERA            MULEBA   51631.0   51767.0
# 85        MOROGORO            KILOSA   50740.0   53940.0
# 67            MARA      MUSOMA RURAL   49746.0   48706.0
# 119          RUKWA  SUMBAWANGA RURAL   49698.0   49326.0
# 14          DODOMA            KONDOA   48859.0   55869.0
# 121         RUVUMA            MBINGA   48552.0   49264.0
# 151         TABORA            URAMBO   47703.0   45939.0
# 144        SINGIDA     SINGIDA RURAL   44844.0   46895.0
# 71            MARA      TARIME RURAL   43986.0   42706.0
# 65            MARA             BUNDA   43433.0   42739.0
# 141        SINGIDA            IRAMBA   41539.0   40906.0
# 98          MWANZA            KWIMBA   40755.0   43045.0
# 155          TANGA           KILINDI   39676.0   40330.0
# 103         MWANZA           UKEREWE   39612.0   40203.0
# 17           GEITA           BUKOMBE   39490.0   40178.0
# 18           GEITA             CHATO   39377.0   38393.0
# ..             ...               ...       ...       ...
# 12          DODOMA            CHEMBA       NaN       NaN
# 20           GEITA       GEITA URBAN       NaN       NaN
# 21           GEITA            MBOGWE       NaN       NaN
# 22           GEITA       NYANG'HWALE       NaN       NaN
# 31          KAGERA            KYERWA       NaN       NaN
# 35          KATAVI             MLELE       NaN       NaN
# 38          KATAVI            NSIMBO       NaN       NaN
# 39          KIGOMA           BUHIGWE       NaN       NaN
# 40          KIGOMA           KAKONKO       NaN       NaN
# 45          KIGOMA            UVINZA       NaN       NaN
# 66            MARA           BUTIAMA       NaN       NaN
# 72            MARA         TARIME TC       NaN       NaN
# 73           MBEYA          BUSOKELO       NaN       NaN
# 81           MBEYA             MOMBA       NaN       NaN
# 83        MOROGORO             GAIRO       NaN       NaN
# 91          MTWARA      MASASI URBAN       NaN       NaN
# 105         NJOMBE      MAKAMBAKO TC       NaN       NaN
# 109         NJOMBE      WANGING'OMBE       NaN       NaN
# 117          RUKWA           KALAMBO       NaN       NaN
# 123         RUVUMA             NYASA       NaN       NaN
# 128      SHINYANGA      KAHAMA URBAN       NaN       NaN
# 130      SHINYANGA           MSALALA       NaN       NaN
# 133      SHINYANGA            USHETU       NaN       NaN
# 135         SIMIYU     BARIADI URBAN       NaN       NaN
# 136         SIMIYU            BUSEGA       NaN       NaN
# 137         SIMIYU           ITILIMA       NaN       NaN
# 140        SINGIDA            IKUNGI       NaN       NaN
# 143        SINGIDA           MKALAMA       NaN       NaN
# 147         TABORA            KALIUA       NaN       NaN
# 153          TANGA           BUMBULI       NaN       NaN
#
# [163 rows x 4 columns]

# %% [markdown]
# Sorting by region descending

# %%
data.sort_values(by=['REGION'],ascending=False)
# Out:
#             REGION       DISTRICT      MALE    FEMALE
# 162          TANGA    TANGA URBAN   26555.0   26487.0
# 157          TANGA  KOROGWE URBAN    6240.0    6057.0
# 154          TANGA        HANDENI   35554.0   35379.0
# 155          TANGA        KILINDI   39676.0   40330.0
# 156          TANGA  KOROGWE RURAL   25306.0   25000.0
# 153          TANGA        BUMBULI       NaN       NaN
# 158          TANGA        LUSHOTO   69395.0   70238.0
# 159          TANGA         MKINGA   12799.0   12568.0
# 160          TANGA         MUHEZA   19672.0   19650.0
# 161          TANGA        PANGANI    4903.0    4925.0
# 152         TABORA           UYUI   38260.0   36122.0
# 151         TABORA         URAMBO   47703.0   45939.0
# 150         TABORA   TABORA URBAN   22901.0   23134.0
# 149         TABORA        SIKONGE   15929.0   15217.0
# 148         TABORA          NZEGA   51661.0   50067.0
# 147         TABORA         KALIUA       NaN       NaN
# 146         TABORA         IGUNGA   35226.0   35892.0
# 142        SINGIDA        MANYONI   25158.0   24947.0
# 140        SINGIDA         IKUNGI       NaN       NaN
# 141        SINGIDA         IRAMBA   41539.0   40906.0
# 144        SINGIDA  SINGIDA RURAL   44844.0   46895.0
# 143        SINGIDA        MKALAMA       NaN       NaN
# 145        SINGIDA  SINGIDA URBAN   13385.0   14007.0
# 139         SIMIYU          MEATU   30721.0   32209.0
# 138         SIMIYU          MASWA   31095.0   33992.0
# 137         SIMIYU        ITILIMA       NaN       NaN
# 136         SIMIYU         BUSEGA       NaN       NaN
# 135         SIMIYU  BARIADI URBAN       NaN       NaN
# 134         SIMIYU  BARIADI RURAL   75089.0   79153.0
# 130      SHINYANGA        MSALALA       NaN       NaN
# ..             ...            ...       ...       ...
# 29          KAGERA   BUKOBA URBAN   10377.0   10654.0
# 28          KAGERA   BUKOBA RURAL   27577.0   28264.0
# 27          KAGERA     BIHARAMULO   20620.0   20865.0
# 23          IRINGA   IRINGA RURAL   28608.0   28990.0
# 25          IRINGA         KILOLO   29161.0   30316.0
# 24          IRINGA   IRINGA URBAN   13115.0   13449.0
# 26          IRINGA        MUFINDI   32996.0   34659.0
# 22           GEITA    NYANG'HWALE       NaN       NaN
# 21           GEITA         MBOGWE       NaN       NaN
# 20           GEITA    GEITA URBAN       NaN       NaN
# 19           GEITA          GEITA  115698.0  116328.0
# 18           GEITA          CHATO   39377.0   38393.0
# 17           GEITA        BUKOMBE   39490.0   40178.0
# 15          DODOMA         KONGWA   27169.0   30264.0
# 16          DODOMA        MPWAPWA   32176.0   31646.0
# 14          DODOMA         KONDOA   48859.0   55869.0
# 13          DODOMA   DODOMA URBAN   35137.0   36806.0
# 12          DODOMA         CHEMBA       NaN       NaN
# 11          DODOMA       CHAMWINO   26483.0   28264.0
# 10          DODOMA           BAHI   15672.0   15967.0
# 8    DAR ES SALAAM      KINONDONI   91554.0   93921.0
# 7    DAR ES SALAAM          ILALA   73129.0   78309.0
# 9    DAR ES SALAAM         TEMEKE   85118.0   88813.0
# 2           ARUSHA         KARATU   23303.0   23181.0
# 4           ARUSHA           MERU   33854.0   34171.0
# 3           ARUSHA        LONGIDO   10584.0    9045.0
# 1           ARUSHA   ARUSHA URBAN   36315.0   36993.0
# 5           ARUSHA        MONDULI   13689.0   12888.0
# 6           ARUSHA     NGORONGORO   16017.0   12162.0
# 0           ARUSHA   ARUSHA RURAL   32475.0   33698.0
#
# [163 rows x 4 columns]

# %% [markdown]
#  **Putting it together**: Select Districts and Region  with Male > 50000 and Female > 30000, sorted by Districts

# %%
temp_data = data[(data.MALE > 50000) & (data.FEMALE >30000)]
temp_data2 = temp_data[['DISTRICT', 'REGION']]
temp_data2.sort_values(by="DISTRICT", ascending=0)
# Out:
#           DISTRICT         REGION
# 9           TEMEKE  DAR ES SALAAM
# 102      SENGEREMA         MWANZA
# 148          NZEGA         TABORA
# 33          MULEBA         KAGERA
# 80           MBOZI          MBEYA
# 99            MAGU         MWANZA
# 158        LUSHOTO          TANGA
# 8        KINONDONI  DAR ES SALAAM
# 85          KILOSA       MOROGORO
# 43    KIGOMA RURAL         KIGOMA
# 41          KASULU         KIGOMA
# 30         KARAGWE         KAGERA
# 127      KAHAMA DC      SHINYANGA
# 7            ILALA  DAR ES SALAAM
# 19           GEITA          GEITA
# 134  BARIADI RURAL         SIMIYU

# %% [markdown]
# The above code is equivalent to:

# %%
data[(data.MALE > 50000) & (data.FEMALE >30000)][['DISTRICT', 'REGION']].sort_values(by="DISTRICT", ascending=0)
# Out:
#           DISTRICT         REGION
# 9           TEMEKE  DAR ES SALAAM
# 102      SENGEREMA         MWANZA
# 148          NZEGA         TABORA
# 33          MULEBA         KAGERA
# 80           MBOZI          MBEYA
# 99            MAGU         MWANZA
# 158        LUSHOTO          TANGA
# 8        KINONDONI  DAR ES SALAAM
# 85          KILOSA       MOROGORO
# 43    KIGOMA RURAL         KIGOMA
# 41          KASULU         KIGOMA
# 30         KARAGWE         KAGERA
# 127      KAHAMA DC      SHINYANGA
# 7            ILALA  DAR ES SALAAM
# 19           GEITA          GEITA
# 134  BARIADI RURAL         SIMIYU

# %% [markdown]
# <div class="alert alert-success">
#     <b>Activity 4</b>: Select all universities with Bachelor enrollment greater than 100, Masters enrollment greater than 50 and and atleast 10 PhD enrollment.
# </div>

# %% [markdown]
# <div class="alert alert-info" style="font-size:120%">
# <b>NOTE</b>: <br><br>
#
# So as a summary, `[]` provides the following convenience shortcuts:
#
# * **Series**: selecting a **label**: `s[label]`
# * **DataFrame**: selecting a single or multiple **columns**:`df['col']` or `df[['col1', 'col2']]`
# * **DataFrame**: slicing or filtering the **rows**: `df['row_label1':'row_label2']` or `df[mask]`
#
# </div>

# %%
df = pd.read_csv('data/university.csv')
df.head()

# %% [markdown]
# ## Basic operations on Series and DataFrames
#
# Just like with numpy arrays, many operations are element-wise. We can apply NumPy ufuncs (element-wise array methods) to pandas objects.

# %%
np.max(data.FEMALE)
# Out:
# 116328.0

# %%
data['FEMALE'].max()
# Out:
# 116328.0

# %%
data["TOTAL"]=data[["FEMALE", "MALE"]].sum(axis=1)
data.head()
# Out:
#    REGION      DISTRICT     MALE   FEMALE    TOTAL
# 0  ARUSHA  ARUSHA RURAL  32475.0  33698.0  66173.0
# 1  ARUSHA  ARUSHA URBAN  36315.0  36993.0  73308.0
# 2  ARUSHA        KARATU  23303.0  23181.0  46484.0
# 3  ARUSHA       LONGIDO  10584.0   9045.0  19629.0
# 4  ARUSHA          MERU  33854.0  34171.0  68025.0

# %% [markdown]
# ### Function Application and Mapping

# %% [markdown]
# When you have an operation which does NOT work element-wise or you have no idea how to do it directly in Pandas, use the **apply()** function. A typical use case is with a custom written or a **lambda** function

# %%
f = lambda x: (x - x.mean())/x.std()

# %%
data[["FEMALE", "MALE", "TOTAL"]].apply(f)
# Out:
#        FEMALE      MALE     TOTAL
# 0    0.124343  0.092877  0.369988
# 1    0.294130  0.296550  0.539462
# 2   -0.417582 -0.393603 -0.097673
# 3   -1.145990 -1.068215 -0.735545
# 4    0.148716  0.166019  0.413978
# 5   -0.947966 -0.903527 -0.570513
# 6   -0.985376 -0.780050 -0.532462
# 7    2.423084  2.249153  2.395239
# 8    3.227548  3.226410  3.203700
# 9    2.964340  2.885046  2.929502
# 10  -0.789309 -0.798349 -0.450278
# 11  -0.155663 -0.224937  0.098593
# 12        NaN       NaN -1.201781
# 13   0.284494  0.234069  0.507040
# 14   1.266783  0.961880  1.285763
# 15  -0.052606 -0.188551  0.162392
# 16   0.018607  0.077018  0.314146
# 17   0.458249  0.464951  0.690527
# 18   0.366270  0.458957  0.645445
# 19   4.382149  4.507001  4.309400
# 20        NaN       NaN -1.201781
# 21        NaN       NaN -1.201781
# 22        NaN       NaN -1.201781
# 23  -0.118253 -0.112227  0.166311
# 24  -0.919058 -0.933971 -0.570822
# 25  -0.049926 -0.082896  0.210942
# 26   0.173862  0.120511  0.405189
# 27  -0.536923 -0.535908 -0.216412
# 28  -0.155663 -0.166911  0.124578
# 29  -1.063081 -1.079194 -0.702244
# ..        ...       ...       ...
# 133       NaN       NaN -1.201781
# 134  2.466574  2.353111  2.461841
# 135       NaN       NaN -1.201781
# 136       NaN       NaN -1.201781
# 137       NaN       NaN -1.201781
# 138  0.139493  0.019683  0.344193
# 139  0.047617 -0.000154  0.292959
# 140       NaN       NaN -1.201781
# 141  0.495761  0.573629  0.756488
# 142 -0.326583 -0.295214 -0.011666
# 143       NaN       NaN -1.201781
# 144  0.804366  0.748925  0.977243
# 145 -0.890305 -0.919651 -0.551155
# 146  0.237397  0.238790  0.487444
# 147       NaN       NaN -1.201781
# 148  0.967815  1.110497  1.214506
# 149 -0.827956 -0.784718 -0.461988
# 150 -0.420004 -0.414925 -0.108338
# 151  0.755105  0.900566  1.022444
# 152  0.249249  0.399712  0.564972
# 153       NaN       NaN -1.201781
# 154  0.210963  0.256187  0.483050
# 155  0.466081  0.474816  0.698555
# 156 -0.323852 -0.287364 -0.006892
# 157 -1.299958 -1.298619 -0.909698
# 158  2.007197  2.051103  2.114841
# 159 -0.964455 -0.950732 -0.599254
# 160 -0.599530 -0.586190 -0.267788
# 161 -1.358288 -1.369533 -0.968343
# 162 -0.247229 -0.221118  0.058095
#
# [163 rows x 3 columns]

# %% [markdown]
# ### Unique Values, Value Counts, and Membership

# %% [markdown]
# The `unique` ,gives  an array of the unique values in a series. Fo example suppose we want to know different wealth index category available in the dataset.

# %%
data['REGION'].unique()
# Out:
# array(['ARUSHA', 'DAR ES SALAAM', 'DODOMA', 'GEITA', 'IRINGA', 'KAGERA',
#        'KATAVI', 'KIGOMA', 'KILIMANJARO', 'LINDI', 'MANYARA', 'MARA',
#        'MBEYA', 'MOROGORO', 'MTWARA', 'MWANZA', 'NJOMBE', 'PWANI',
#        'RUKWA', 'RUVUMA', 'SHINYANGA', 'SIMIYU', 'SINGIDA', 'TABORA',
#        'TANGA'], dtype=object)

# %% [markdown]
# `value_counts` computes a Series
# containing value frequencies

# %%
data['REGION'].value_counts()
# Out:
# TANGA            10
# MBEYA            10
# KAGERA            8
# MARA              8
# MWANZA            7
# ARUSHA            7
# MOROGORO          7
# TABORA            7
# SHINYANGA         7
# KIGOMA            7
# DODOMA            7
# KILIMANJARO       7
# MTWARA            7
# PWANI             7
# GEITA             6
# MANYARA           6
# SINGIDA           6
# LINDI             6
# RUVUMA            6
# NJOMBE            6
# SIMIYU            6
# IRINGA            4
# RUKWA             4
# KATAVI            4
# DAR ES SALAAM     3
# Name: REGION, dtype: int64

# %% [markdown]
# `value_counts` is
# also available as a top-level pandas method that can be used with any array or
# sequence

# %%
pd.value_counts(data['REGION'])
# Out:
# TANGA            10
# MBEYA            10
# KAGERA            8
# MARA              8
# MWANZA            7
# ARUSHA            7
# MOROGORO          7
# TABORA            7
# SHINYANGA         7
# KIGOMA            7
# DODOMA            7
# KILIMANJARO       7
# MTWARA            7
# PWANI             7
# GEITA             6
# MANYARA           6
# SINGIDA           6
# LINDI             6
# RUVUMA            6
# NJOMBE            6
# SIMIYU            6
# IRINGA            4
# RUKWA             4
# KATAVI            4
# DAR ES SALAAM     3
# Name: REGION, dtype: int64

# %% [markdown]
# ### `isin` and `string` methods
#
# The `isin` method of Series is very useful to select rows that may contain certain values:

# %%
data[data['REGION'].isin(['MWANZA'])]
# Out:
#      REGION   DISTRICT     MALE   FEMALE     TOTAL
# 97   MWANZA    ILEMELA  34923.0  36364.0   71287.0
# 98   MWANZA     KWIMBA  40755.0  43045.0   83800.0
# 99   MWANZA       MAGU  58405.0  59754.0  118159.0
# 100  MWANZA   MISUNGWI  33284.0  34264.0   67548.0
# 101  MWANZA  NYAMAGANA  36646.0  38017.0   74663.0
# 102  MWANZA  SENGEREMA  75842.0  75419.0  151261.0
# 103  MWANZA    UKEREWE  39612.0  40203.0   79815.0

# %% [markdown]
# Let's say we want to select all data for which the district starts with a 'B'. In Python, when having a string, we could use the `startswith` method:

# %%
data[data['DISTRICT'].str.startswith('B')]
# Out:
#       REGION       DISTRICT     MALE   FEMALE     TOTAL
# 10    DODOMA           BAHI  15672.0  15967.0   31639.0
# 17     GEITA        BUKOMBE  39490.0  40178.0   79668.0
# 27    KAGERA     BIHARAMULO  20620.0  20865.0   41485.0
# 28    KAGERA   BUKOBA RURAL  27577.0  28264.0   55841.0
# 29    KAGERA   BUKOBA URBAN  10377.0  10654.0   21031.0
# 39    KIGOMA        BUHIGWE      NaN      NaN       0.0
# 59   MANYARA   BABATI RURAL  29144.0  30074.0   59218.0
# 60   MANYARA   BABATI URBAN   7910.0   8081.0   15991.0
# 65      MARA          BUNDA  43433.0  42739.0   86172.0
# 66      MARA        BUTIAMA      NaN      NaN       0.0
# 73     MBEYA       BUSOKELO      NaN      NaN       0.0
# 110    PWANI       BAGAMOYO  26931.0  27509.0   54440.0
# 134   SIMIYU  BARIADI RURAL  75089.0  79153.0  154242.0
# 135   SIMIYU  BARIADI URBAN      NaN      NaN       0.0
# 136   SIMIYU         BUSEGA      NaN      NaN       0.0
# 153    TANGA        BUMBULI      NaN      NaN       0.0

# %% [markdown]
# ## Data summarization and  Descriptive Statistics
#
# Descriptive statistics can give you great insight into the shape of each attribute. The **describe()** function on the Pandas DataFrame lists 8 statistical properties of each attribute:
#
# * Count
# * Mean
# * Standard Devaition
# * Minimum Value
# * 25th Percentile
# * 50th Percentile (Median)
# * 75th Percentile
# * Maximum Value
#
# For example to obtain the statistics summary  for Cities data.

# %% [markdown]
# Calling DataFrame’s sum method returns a Series containing column sums:

# %%
data[['FEMALE', 'MALE']].sum()
# Out:
# FEMALE    4160892.0
# MALE      4086280.0
# dtype: float64

# %% [markdown]
# Passing axis='columns' or axis=1 sums across the columns instead:

# %%
data[['FEMALE', 'MALE']].sum(axis=1)

# %% [markdown]
# NA values are excluded unless the entire slice (row or column in this case) is NA. This can be disabled with the skipna option:

# %%
data[['FEMALE', 'MALE']].sum(axis=1,skipna=False)

# %% [markdown]
# Some methods, like idxmin and idxmax , return indirect statistics like the index value
# where the minimum or maximum values are attained

# %%
data[['FEMALE', 'MALE']].idxmax()

# %% [markdown]
# describe is one
# such example, producing multiple summary statistics in one shot

# %%
data.describe()

# %% [markdown]
# To obtain descriptive statistics of a particular column use:

# %%
data['MALE'].mean()

# %% [markdown]
# <div class="alert alert-success">
#
# <b>Activity 5</b>:
#
#  <ul>
#   <li>Select all rows for Female stduents in the university dataset and calculate the mean of female students enrolled in bachelor program. Do the same for the male students.</li>
# </ul>
# </div>

# %% [markdown]
# ## References
#
# * [Jupyter Notebooks for the Python Data Science Handbook](https://github.com/jakevdp/PythonDataScienceHandbook)
# * [Pandas & Seaborn - A guide to handle & visualize data elegantly](https://tryolabs.com/blog/2017/03/16/pandas-seaborn-a-guide-to-handle-visualize-data-elegantly/)
